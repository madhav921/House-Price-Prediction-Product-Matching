# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import csv

# %%
path = "DS - Assignment Part 2 data set/"
df1 = pd.read_csv(path+"flipkart_com-ecommerce_sample.csv")
df2 = pd.read_csv(path+"amz_com-ecommerce_sample.csv", encoding= 'unicode_escape')
print(df1.head(5))
print(df2.head(5))
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %% [markdown]
# ### Data Analysis and Product Matching

# %%
prod = input("Product name: ")
df[df["product_name"] == prod]
# Out:
# Product name: Alisha Solid Women's Cycling Shorts
#                              uniq_id            crawl_timestamp  \
# 0   c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 3   0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 6   ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# 9   4044c0ac52c1ee4b28777417651faf42  2016-03-25 22:59:23 +0000
# 13  9aacdecceb404c74abddc513fd2756a8  2016-03-25 22:59:23 +0000
# 15  d95b0456a0350bc42f2393c6e84b0f09  2016-03-25 22:59:23 +0000
# 21  ea98a65ad1e1b8688eddf89fbc7b3e27  2016-03-25 22:59:23 +0000
#
#                                           product_url  \
# 0   http://www.flipkart.com/alisha-solid-women-s-c...
# 3   http://www.flipkart.com/alisha-solid-women-s-c...
# 6   http://www.flipkart.com/alisha-solid-women-s-c...
# 9   http://www.flipkart.com/alisha-solid-women-s-c...
# 13  http://www.flipkart.com/alisha-solid-women-s-c...
# 15  http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
brand = input("Brand name: ")
price = input("Price: ")
df[df["brand"] == brand]
# Out:
# Brand name: AW
# Price: 9
#                                uniq_id            crawl_timestamp  \
# 2     f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 7689  c666e51ec698f56a304d5fd9c1687229  2016-03-07 04:40:26 +0000
# 7695  1ed2415ea35fd4300f751d43ea82b8bd  2016-03-07 04:40:26 +0000
# 7698  bb7d2b997018b1558b8ae386171c21c4  2016-03-07 04:40:26 +0000
# 7703  8e2ddc626a7c10d2f5d142070507fd13  2016-03-07 04:40:26 +0000
#
#                                             product_url  \
# 2     http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 7689  http://www.flipkart.com/aw-high-speed-charge-s...
# 7695  http://www.flipkart.com/aw-high-power-usb-ipho...
# 7698  http://www.flipkart.com/aw-high-power-usb-ipho...
# 7703  http://www.flipkart.com/aw-high-speed-charge-s...
#
#                                            product_name  \
# 2                                            AW Bellies
# 7689  AW High Speed Charge and Sync Usb for Iphone 6...
# ...

# %%
# Convert data to json to access respective specifications of the product

temp = df1[df1["brand"] == "Alisha"]["product_specifications"][0]
temp1 = temp.replace("=>",":")
res = json.loads(temp1)
res = eval(temp1)
print(res['product_specification'])
# Out:
# [{'key': 'Number of Contents in Sales Package', 'value': 'Pack of 3'}, {'key': 'Fabric', 'value': 'Cotton Lycra'}, {'key': 'Type', 'value': 'Cycling Shorts'}, {'key': 'Pattern', 'value': 'Solid'}, {'key': 'Ideal For', 'value': "Women's"}, {'value': 'Gentle Machine Wash in Lukewarm Water, Do Not Bleach'}, {'key': 'Style Code', 'value': 'ALTHT_3P_21'}, {'value': '3 shorts'}]

# %%
df[df["brand"] == "Alisha"]["product_category_tree"][0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
df3 = df1.drop(df1.columns[[0,1,2,4,5,8,9,10,11,12,13,14]], axis=1)
df4 = df2.drop(df2.columns[[0,1,2,4,5,8,9,10,11,12,13,14]], axis=1)
result = pd.concat([df3, df4], axis=1)
# result.to_csv('final_DS_A1.csv')

# %%
name1 = df1["product_name"]
print(name1.dtype)
# Out:
# object

# %%
header = [name1]
with open('final_DS_A1.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
res_df = pd.read_csv("final_DS_A1.csv")

# %% [markdown]
# ### Input a product name to get its Flipkart and Amazon details

# %%
prod = input("Product name: ")
res_df[res_df["Product name in Flipkart"] == prod]
# Out:
# Product name: AW High Power Usb for Iphone 4 Lightning Cable
#                             Product name in Flipkart  \
# 7698  AW High Power Usb for Iphone 4 Lightning Cable
#
#       Retail Price in Flipkart  Discounted Price in Flipkart  \
# 7698                     499.0                         297.0
#
#                               Product name in Amazon  Retail Price in Amazon  \
# 7698  AW High Power Usb for Iphone 4 Lightning Cable                     497
#
#       Discounted Price in Amazon
# 7698                         351
